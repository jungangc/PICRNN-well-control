# %%
import numpy as np
loss = np.load("train_loss.npy")
loss_norm = loss/loss[0]
import matplotlib.pyplot as plt
plt.semilogy(loss_norm)
# plt.ylim([1e-2,1])

# # change the label size
# im.figure.axes[0].tick_params(axis="both", labelsize=21)
plt.xlabel('Epochs', fontsize=16)
# plt.ylabel('normalized loss', fontsize=16)
plt.tick_params(axis='y', which='major', labelsize=14)
plt.title('Training loss history', fontsize=20)
plt.show()

# %%
loss
# Out:
# array([742.10083008, 734.82940674, 735.14355469, ...,  40.35595703,
#         40.44603729,  42.21550369])
